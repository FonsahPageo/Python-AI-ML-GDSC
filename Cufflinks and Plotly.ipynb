# %% [markdown]
# ## Cufflinks

# %%
# Cufflinks is a python library that connects with plotly
# so that we can create charts directly on dataframes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.DataFrame(np.random.rand(500, 4), columns = ['a', 'b', 'c', 'd'])
df1
# Out:
#             a         b         c         d
# 0    0.578082  0.500606  0.225159  0.908726
# 1    0.624490  0.154774  0.675676  0.589977
# 2    0.514547  0.450611  0.606183  0.871514
# 3    0.019829  0.100679  0.112473  0.999309
# 4    0.629056  0.698285  0.359363  0.052106
# ..        ...       ...       ...       ...
# 495  0.304805  0.377026  0.571788  0.043967
# 496  0.997876  0.727371  0.193065  0.221209
# 497  0.688448  0.628838  0.753755  0.345981
# 498  0.142089  0.910653  0.867506  0.345394
# 499  0.012720  0.873433  0.539438  0.656506
#
# [500 rows x 4 columns]

# %%
df2 = pd.DataFrame({'x':['p', 'q', 'r'], 'y':[1, 2, 3]})
df2
# Out:
#    x  y
# 0  p  1
# 1  q  2
# 2  r  3

# %%
df1.iplot(kind = 'scatter', x = 'a', y = 'b', mode = 'markers')
# Out:
# <div>                            <div id="604e5c0b-a7c8-4ed2-ae9e-3a2a2aea5e18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind = 'bar', x = 'x', y = 'y')
# Out:
# <div>                            <div id="3cf22415-22c8-4ad6-8969-1786077662c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
