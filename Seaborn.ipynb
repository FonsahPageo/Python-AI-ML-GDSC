# %% [markdown]
# # Intoduction to Seaborn

# %%
#Python data visualization library based on matplotlib
#it allows the creation of statistical graphics
#allows comparison b/w multiple variables
#supports multi-plot grids
#univariate and bivariate visualizations
#diff colour palettes available
#estimates and plots linear regression automatically

# %% [markdown]
# # Seaborn Vs Matplotlib

# %%
#Seaborn actually works on dataframes wheareas Matplotlib doesn't
#Seaborn comes with numerous customized themes and high-level interfaces
#whereas matplotlib settings are difficult to figure out.

# %% [markdown]
# # Seaborn functions

# %%
#statistical analysis, process of understanding relationships between variables of a dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = sns.load_dataset('flights')
sns.relplot(x = "passengers", y = "month", data = a)

# %%
sns.relplot(x = "passengers", y = "month", hue = "year", data = a)

# %%
b = sns.load_dataset("tips")
sns.relplot(x = "time", y = "tip", data = b, kind = "line")

# %%
sns.catplot(x = "day", y = "total_bill", kind = "boxen", data = b)

# %%
from scipy import stats

# %%
c = np.random.normal(loc = 5, size = 100, scale = 2)
sns.displot(c)

# %%
d = sns.load_dataset("iris")
e = sns.FacetGrid(d, col = "species")
e.map(plt.hist, "sepal_length")

# %%
sns.set(style = "white")
f = sns.load_dataset("flights")
g = sns.PairGrid(a)
g.map(plt.scatter)

# %%
sns.set(style = "darkgrid")
f = sns.load_dataset("flights")
g = sns.PairGrid(a)
g.map(plt.scatter)
